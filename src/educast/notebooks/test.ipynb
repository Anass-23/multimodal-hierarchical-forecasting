# %%
from pathlib import Path
from educast.constants import (
    EDUCAST, DATA_DIR, 
    RAW_DATA_DIR, RTU_DATA_DIR
)

const = [
    EDUCAST,
    DATA_DIR,
    RAW_DATA_DIR,
    RTU_DATA_DIR
]

for c in const:
    print(f'{type(c).__name__}, {c}')
# Out:
# str, EduCast: A multimodal hierarchical forecasting framework for university enrollments
# PosixPath, /Users/anassanhari/EPSEM/TFM/multimodal-hierarchical-forecasting/data
# PosixPath, /Users/anassanhari/EPSEM/TFM/multimodal-hierarchical-forecasting/data/raw
# PosixPath, /Users/anassanhari/EPSEM/TFM/multimodal-hierarchical-forecasting/data/raw/RTU_data_private

# %%
try:
    num_dirs = sum(1 for p in RTU_DATA_DIR.iterdir() if p.is_dir())
    print(num_dirs)
except Exception as e:
    print("Error listing RTU_DATA_DIR:", e)
# Out:
# 2

# %%
try:
    num_dirs = sum(1 for p in Path(RTU_DATA_DIR/'21-22-P').iterdir() if p.is_dir())
    print(num_dirs)
except Exception as e:
    print("Error listing RTU_DATA_DIR:", e)
# Out:
# 2995

# %%
try:
    num_dirs = sum(1 for p in Path(RTU_DATA_DIR/'21-22-R').iterdir() if p.is_dir())
    print(num_dirs)
except Exception as e:
    print("Error listing RTU_DATA_DIR:", e)
# Out:
# 3523
